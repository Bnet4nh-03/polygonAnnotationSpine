# %% [markdown]
# Xác định bài toán
#
#      ↓
#
# Chuẩn bị dữ liệu (ảnh + nhãn)
#
#      ↓
#
# Tiền xử lý (resize, normalize, augmentation)
#
#      ↓
#
# Xây dựng mô hình (CNN, ResNet, YOLO…)
#
#      ↓
#
# Huấn luyện (loss, optimizer, epoch)
#
#      ↓
#
# Đánh giá (accuracy, IoU, Dice, F1)
#
#      ↓
#
# Ứng dụng (dự đoán ảnh mới, triển khai)

# %% [markdown]
# # Liner Regresion
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Logistic Regresion
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Support Vector Machine
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # K-nearest Machine
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Naive Bayes
#
# ![Screenshot 2025-09-23 202939.png](data:image/png;base64,...)

# %% [markdown]
# # Decision Tree
#
#
# ![image.png](data:image/png;base64,...)
